# %% [markdown]
# ## Scaleway Object Storage - Testing
#
# https://www.simplecto.com/using-django-and-boto3-with-scaleway-object-storage/
#
# * `AWS_ACCESS_KEY_ID` and `AWS_SECRET_ACCESS_KEY` can be obtained from the [credentials control panel](https://console.scaleway.com/project/credentials) under API Keys.
# * `AWS_STORAGE_BUCKET_NAME` is the name of the bucket you create on [objects administration page](https://console.scaleway.com/object-storage/buckets)
# * `AWS_DEFAULT_ACL` is set to public-read so that the objects can be pulled from a URL without any access keys or time-limited signatures.
# * `AWS_S3_REGION_NAME` and `AWS_S3_ENDPOINT_URL` should be configured so that `boto3` knows to point to the Scaleway resources.
#
# All of these are references in the Scaleways docs on Object Storage.
#
# ### Resources:
# * https://github.com/liormizr/s3path/blob/master/docs/advance.rst
# * https://www.scaleway.com/en/docs/object-storage-feature/
# * https://www.scaleway.com/en/docs/how-to-migrate-object-storage-buckets-with-rclone/
# * https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/s3.html

# %%
import tomli
from pathlib import Path
import boto3

# %%
boto3.__version__
# Out:
# '1.17.107'

# %%
APP_CONFIG_FILE = 'app_config.toml'

# %%
with open(Path('..')/APP_CONFIG_FILE, encoding="utf-8") as f:
    app_config = tomli.load(f)

# %%
AWS_ACCESS_KEY_ID = app_config['AWS']['AWS_ACCESS_KEY_ID']
AWS_SECRET_ACCESS_KEY = app_config['AWS']['AWS_SECRET_ACCESS_KEY']
AWS_STORAGE_BUCKET_NAME = app_config['AWS']['AWS_STORAGE_BUCKET_NAME']
AWS_DEFAULT_ACL = app_config['AWS']['AWS_DEFAULT_ACL']
AWS_S3_REGION_NAME = app_config['AWS']['AWS_S3_REGION_NAME']
AWS_S3_ENDPOINT_URL =  app_config['AWS']['AWS_S3_ENDPOINT_URL']

# %%
AWS_S3_ENDPOINT_URL
# Out:
# 'https://s3.fr-par.scw.cloud'

# %%
s3 = boto3.client('s3', 
        region_name=AWS_S3_REGION_NAME, 
        endpoint_url=AWS_S3_ENDPOINT_URL, 
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

# %%
def download_s3_folder(s3, bucket_name, s3_folder, local_dir=None):
    filecount = 0
    files = []
    if not local_dir.exists():
        Path.mkdir(local_dir)
    print('Writing files to local dir: ' + Path(local_dir).as_posix())
    print(bucket_name)
    bucket_list=s3.list_objects(Bucket=bucket_name)['Contents']
    for s3_key in bucket_list:
        s3_object = s3_key['Key']
        if not s3_object.endswith("/"):
            filepath = Path(local_dir)/s3_object
            print(filepath.as_posix())
            s3.download_file(bucket_name, s3_object, filepath.as_posix())
            filecount+=1
            files.append(s3_object)
        else:
            if not (Path(local_dir)/s3_object).exists():
                print('Creating dir: ' + (Path(local_dir)/s3_object).as_posix())
                Path.mkdir(Path(local_dir)/s3_object)
    return filecount, files

# %%
def list_s3_folder(s3, bucket_name, s3_folder):
    return [s3_key['Key'] for s3_key in s3.list_objects(Bucket=bucket_name)['Contents'] if s3_key['Key'].endswith("/")]

# %%
list_s3_folder(s3, AWS_STORAGE_BUCKET_NAME, 'data/FIT')
# Out:
# ['data/']

# %%
filecount, files = download_s3_folder(s3, AWS_STORAGE_BUCKET_NAME, 'data/FIT', Path.home()/'tmp/test-scaleway')
# Out:
# Writing files to local dir: /Users/mjboothaus/tmp/test-scaleway
# emmaus-walking
# /Users/mjboothaus/tmp/test-scaleway/data/FIT/B2M/2020-07-13-085452-Walking-Michael and Ai Leen’s Apple Watch.fit
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_6/5btwyp417kb5tky1dhxm68000000gn/T/ipykernel_31729/2085765848.py in <module>
# ----> 1 filecount, files = download_s3_folder(s3, AWS_STORAGE_BUCKET_NAME, 'data/FIT', Path.home()/'tmp/test-scaleway')
#
# /var/folders/_6/5btwyp417kb5tky1dhxm68000000gn/T/ipykernel_31729/2557369277.py in download_s3_folder(s3, bucket_name, s3_folder, local_dir)
#      12             filepath = Path(local_dir)/s3_object
#      13             print(filepath.as_posix())
# ---> 14             s3.download_file(bucket_name, s3_object, filepath.as_posix())
#      15             filecount+=1
#      16             files.append(s3_object)
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     168     """
#     169     with S3Transfer(self, Config) as transfer:
# --> 170         return transfer.download_file(
#     171             bucket=Bucket, key=Key, filename=Filename,
#     172             extra_args=ExtraArgs, callback=Callback)
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     305             bucket, key, filename, extra_args, subscribers)
#     306         try:
# --> 307             future.result()
#     308         # This is for backwards compatibility where when retries are
#     309         # exceeded we need to throw the same error from boto3 instead of
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/tasks.py in __call__(self)
#     124             # main() method.
#     125             if not self._transfer_coordinator.done():
# --> 126                 return self._execute_main(kwargs)
#     127         except Exception as e:
#     128             self._log_and_set_exception(e)
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/tasks.py in _execute_main(self, kwargs)
#     148         )
#     149
# --> 150         return_value = self._main(**kwargs)
#     151         # If the task is the final task, then set the TransferFuture's
#     152         # value to the return value from main().
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/download.py in _main(self, fileobj, data, offset)
#     569         :param offset: The offset to write the data to.
#     570         """
# --> 571         fileobj.seek(offset)
#     572         fileobj.write(data)
#     573
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/utils.py in seek(self, where, whence)
#     365
#     366     def seek(self, where, whence=0):
# --> 367         self._open_if_needed()
#     368         self._fileobj.seek(where, whence)
#     369
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/utils.py in _open_if_needed(self)
#     348     def _open_if_needed(self):
#     349         if self._fileobj is None:
# --> 350             self._fileobj = self._open_function(self._filename, self._mode)
#     351             if self._start_byte != 0:
#     352                 self._fileobj.seek(self._start_byte)
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/s3transfer/utils.py in open(self, filename, mode)
#     259
#     260     def open(self, filename, mode):
# --> 261         return open(filename, mode)
#     262
#     263     def remove_file(self, filename):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mjboothaus/tmp/test-scaleway/data/FIT/B2M/2020-07-13-085452-Walking-Michael and Ai Leen’s Apple\xa0Watch.fit.4CfeCC67'

# %%
print(str(filecount) + ' files downloaded')
print(files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_6/5btwyp417kb5tky1dhxm68000000gn/T/ipykernel_31380/1659393716.py in <module>
# ----> 1 print(str(filecount) + ' files downloaded')
#       2 print(files)
#
# NameError: name 'filecount' is not defined

# %% [markdown]
# ## Alternate approach - `s3path` library

# %%
import boto3
from s3path import S3Path

# %%
s3 = boto3.client('s3', 
        region_name=AWS_S3_REGION_NAME, 
        endpoint_url=AWS_S3_ENDPOINT_URL, 
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

# %%
boto3.setup_default_session(
        region_name=AWS_S3_REGION_NAME, 
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

# %%
bucket_path = S3Path('/emmaus-walking/')

# %%
bucket_path
# Out:
# S3Path('/emmaus-walking')

# %%
scaleway_resource = boto3.resource('s3',
        endpoint_url=AWS_S3_ENDPOINT_URL, 
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
        region_name=AWS_S3_REGION_NAME)

# %%
AWS_S3_REGION_NAME
# Out:
# 'fr-par'

# %%
from s3path import PureS3Path, register_configuration_parameter
#[path for path in bucket_path.iterdir() if path.is_dir()]

# %%
scaleway_bucket_path = PureS3Path('/emmaus-walking/')

# %%
register_configuration_parameter(scaleway_bucket_path, resource=scaleway_resource)

# %%
scaleway_bucket_path.parts
# Out:
# ('/', 'emmaus-walking')

# %%
def connect_s3_session_scaleway(bucket_name):
        
    session = boto3.session.Session()

    s3_client = session.client(
        service_name='s3',
        region_name=AWS_S3_REGION_NAME,
        use_ssl=True,
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
        endpoint_url=AWS_S3_ENDPOINT_URL,
    )  

    return s3_client

# %%
s3_client = connect_s3_session_scaleway('emmaus-walking')

# %%
s3_client

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_6/5btwyp417kb5tky1dhxm68000000gn/T/ipykernel_31729/3926929135.py in <module>
# ----> 1 s3_client.download_s3_folder('data')
#
# /opt/homebrew/Caskroom/mambaforge/base/envs/emmaus_walking_py38/lib/python3.9/site-packages/botocore/client.py in __getattr__(self, item)
#     641             return event_response
#     642
# --> 643         raise AttributeError(
#     644             "'%s' object has no attribute '%s'" % (
#     645                 self.__class__.__name__, item)
#
# AttributeError: 'S3' object has no attribute 'download_s3_folder'
